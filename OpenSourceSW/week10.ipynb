# %%
#실습 2
str = input("Input Number? ")
a = str.split(" ")
for i in range(0, len(a)):
    a[i] = int(a[i])
print ("Max = ", max(a))

# %%
#실습 3
def split(word):
    return [char for char in word]

def decryption(a):
    result = str("")
    a = a.split(" ")
    b = split(a[1])
    c = split(a[0])
    for i in range(0,len(b)):
        c[i] = chr(ord(c[i]) - 1)
    for i in range(0,len(b)):
        b[i] = chr(ord(b[i]) - 1)
    a[1] =""
    a[0] =""
    for i in range(0,len(b)):
        a[1] +=b[i]
        a[0] +=c[i]
    result = a[1]+" "+a[0]
    print(result)
    main()

def encryption(a):
    result = str("")
    a = a.split(" ")
    b = split(a[1])
    c = split(a[0])
    for i in range(0,len(b)):
        c[i] = chr(ord(c[i]) + 1)
    for i in range(0,len(b)):
        b[i] = chr(ord(b[i]) + 1)
    a[1] =""
    a[0] =""
    for i in range(0,len(b)):
        a[1] +=b[i]
        a[0] +=c[i]
    result = a[1]+" "+a[0]
    print(result)
    main()

def main():
    choice = ''
    choice = input("If you want to encrypt press 1 to decryption press 2? ")
    while choice != 0:
        if choice == '1' :
            str = input("Please Enter Your Word? ")
            encryption(str)
        elif choice == '2' :
            str = input("Please Enter Your Word? ")
            decryption(str)
if __name__ == "__main__":
    main()

# %%
# 실습 4
phone_book={

}
def Search_name(dic, name):
    print("ok")
def main():
    limit = 0
    print("Please Input 10 People")
    while limit != 10:
        phone_input(input("Please Enter Name? "),input("Please Enter No? "))
        limit += 1
        if limit == 10:
            print("Limit Reached")

    choice = ''
    choice = input("To Search Phone.No with Name press 1 , To Search Name with Phone.No press 2 ")
    while choice != '0':
        if choice == '1':
            name = input("Please Enter Name? ")
            x = phone_book.get(name)
            print(x)
            choice = input("To Search Phone.No with Name press 1 , To Search Name with Phone.No press 2 ")
        elif choice == '2':
            key_list = list(phone_book.keys())
            val_list = list(phone_book.values())
            value = input("Please Enter Phone.No? ")
            position = val_list.index(value)
            print(key_list[position])
            choice = input("To Search Phone.No with Name press 1 , To Search Name with Phone.No press 2 ")

def phone_input(x,a):
    phone_book.update({x:a})
       
        
if __name__ == "__main__":
    main()
# Out:
# Please Input 10 People
# Please Enter Name? a
# Please Enter No? 10
# Please Enter Name? b
# Please Enter No? 9
# Please Enter Name? c
# Please Enter No? 8
# Please Enter Name? d
# Please Enter No? 7
# Please Enter Name? e
# Please Enter No? 6
# Please Enter Name? f
# Please Enter No? 5
# Please Enter Name? g
# Please Enter No? 4
# Please Enter Name? h
# Please Enter No? 3
# Please Enter Name? i
# Please Enter No? 2
# Please Enter Name? j
# Please Enter No? 1
# Limit Reached
# To Search Phone.No with Name press 1 , To Search Name with Phone.No press 2 1
# Please Enter Name? a
# 10
# To Search Phone.No with Name press 1 , To Search Name with Phone.No press 2 2
# Please Enter Phone.No? 10
# a
# To Search Phone.No with Name press 1 , To Search Name with Phone.No press 2 0
